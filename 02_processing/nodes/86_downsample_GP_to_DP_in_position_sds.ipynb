# %% [markdown]
# # 86 — Downsample `GP*` channels to `DP*` in the position-coded SDS archive
#
# This notebook reads the 1000 Hz `GP?` channels from the position-coded SDS archive, low-pass filters them, downsamples them to 500 Hz, renames them as `DP?`, and writes the converted day files back into the same SDS archive.
#
# Purpose: after this step, the active-source detection notebooks can process all nodes using only `DP*` channels.
#
# Channel mapping:
#
# ```text
# GPE -> DPE
# GPN -> DPN
# GPZ -> DPZ
# ```
#
# Important safeguards:
#
# - The default mode is `DRY_RUN = True`.
# - Existing `DP*` day files are not overwritten unless `OVERWRITE = True`.
# - AppleDouble files beginning with `._` are ignored.
# - A CSV report is written either way.

# %%
from __future__ import annotations

from pathlib import Path
import pandas as pd
import numpy as np
from obspy import read
from obspy import Stream

# %% [markdown]
# ## Configuration
#
# Set `DRY_RUN = False` only after checking the preview report.

# %%
SDS_ROOT = Path("/Volumes/tachyon/LBSSP_DATA/nodal_sds_position_codes")

# Keep True for the first run. Set False to actually write converted day files.
DRY_RUN = False

# Strongly recommended False. If True, converted GP* files can replace existing DP* day files.
OVERWRITE = True

# Anti-alias low-pass before decimation from 1000 Hz to 500 Hz.
LOWPASS_FREQ_HZ = 225.0
LOWPASS_CORNERS = 4

# Expected rates.
INPUT_SAMPLING_RATE_HZ = 1000.0
OUTPUT_SAMPLING_RATE_HZ = 500.0
DECIMATION_FACTOR = 2

CHANNEL_MAP = {
    "GPE": "DPE",
    "GPN": "DPN",
    "GPZ": "DPZ",
}

REPORT_CSV = SDS_ROOT / "downsample_GP_to_DP_report.csv"

print("SDS_ROOT:", SDS_ROOT)
print("DRY_RUN:", DRY_RUN)
print("OVERWRITE:", OVERWRITE)
# Out:
# SDS_ROOT: /Volumes/tachyon/LBSSP_DATA/nodal_sds_position_codes
# DRY_RUN: False
# OVERWRITE: True

# %% [markdown]
# ## Helper functions

# %%
def is_appledouble(path: Path) -> bool:
    """Return True for macOS AppleDouble metadata files."""
    return path.name.startswith("._")


def parse_sds_filename(path: Path) -> dict:
    """
    Parse an SDS day-file name of the form:

        NET.STA.LOC.CHA.D.YEAR.JDAY

    Returns a dictionary with filename fields.
    """
    parts = path.name.split(".")
    if len(parts) < 7:
        raise ValueError(f"Not an SDS day-file name: {path.name}")

    return {
        "network": parts[0],
        "station": parts[1],
        "location": parts[2],
        "channel": parts[3],
        "dtype": parts[4],
        "year": parts[5],
        "jday": parts[6],
    }


def make_sds_output_path(src_path: Path, sds_root: Path, new_channel: str) -> Path:
    """Construct the SDS output path for the converted day file."""
    meta = parse_sds_filename(src_path)

    return (
        sds_root
        / meta["year"]
        / meta["network"]
        / meta["station"]
        / f"{new_channel}.{meta['dtype']}"
        / f"{meta['network']}.{meta['station']}.{meta['location']}.{new_channel}.{meta['dtype']}.{meta['year']}.{meta['jday']}"
    )


def discover_gp_day_files(sds_root: Path) -> list[Path]:
    """Find all GP? SDS day files in the archive."""
    files = []
    for chan in CHANNEL_MAP:
        files.extend(sds_root.rglob(f"*.{chan}.D.*.*"))

    files = [p for p in files if p.is_file() and not is_appledouble(p)]
    return sorted(set(files))


def summarize_sds_station_channels(sds_root: Path, channel_glob: str = "DPZ") -> pd.DataFrame:
    """Summarize available station/location/channel day files in an SDS archive."""
    rows = []
    for p in sorted(sds_root.rglob(f"*.{channel_glob}.D.*.*")):
        if not p.is_file() or is_appledouble(p):
            continue
        try:
            meta = parse_sds_filename(p)
        except Exception:
            continue
        rows.append({**meta, "path": str(p)})
    return pd.DataFrame(rows)

# %% [markdown]
# ## Preview the files that would be converted
#
# This does not read waveform data yet. It only discovers `GP?` SDS day files and computes the proposed destination path.

# %%
gp_files = discover_gp_day_files(SDS_ROOT)
print(f"Found {len(gp_files)} GP? day files")

preview_rows = []
for src in gp_files:
    meta = parse_sds_filename(src)
    new_channel = CHANNEL_MAP.get(meta["channel"])
    dst = make_sds_output_path(src, SDS_ROOT, new_channel)
    preview_rows.append({
        "network": meta["network"],
        "station": meta["station"],
        "location": meta["location"],
        "old_channel": meta["channel"],
        "new_channel": new_channel,
        "year": meta["year"],
        "jday": meta["jday"],
        "src": str(src),
        "dst": str(dst),
        "dst_exists": dst.exists(),
    })

preview_df = pd.DataFrame(preview_rows)
display(preview_df.head(20))

if len(preview_df):
    display(preview_df.groupby(["network", "location", "old_channel", "new_channel"])["station"].nunique().reset_index(name="n_stations"))
    print("Destination files already exist:", int(preview_df["dst_exists"].sum()))
# Out:
# Found 246 GP? day files
#    network station location old_channel new_channel  year jday  \
# 0       T1   05207       N1         GPE         DPE  2026  136
# 1       T1   05207       N1         GPE         DPE  2026  137
# 2       T1   05207       N3         GPE         DPE  2026  139
# 3       T1   05207       N1         GPN         DPN  2026  136
# 4       T1   05207       N1         GPN         DPN  2026  137
# 5       T1   05207       N3         GPN         DPN  2026  139
# 6       T1   05207       N1         GPZ         DPZ  2026  136
# 7       T1   05207       N1         GPZ         DPZ  2026  137
# 8       T1   05207       N3         GPZ         DPZ  2026  139
# 9       T1   06004       N1         GPE         DPE  2026  136
# 10      T1   06004       N1         GPE         DPE  2026  137
# 11      T1   06004       N3         GPE         DPE  2026  139
# 12      T1   06004       N1         GPN         DPN  2026  136
# 13      T1   06004       N1         GPN         DPN  2026  137
# 14      T1   06004       N3         GPN         DPN  2026  139
# 15      T1   06004       N1         GPZ         DPZ  2026  136
# 16      T1   06004       N1         GPZ         DPZ  2026  137
# 17      T1   06004       N3         GPZ         DPZ  2026  139
# 18      T1   06809       N1         GPE         DPE  2026  136
# 19      T1   06809       N1         GPE         DPE  2026  137
#
#                                                   src  \
# 0   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 1   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 2   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 3   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 4   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 5   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 6   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 7   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 8   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 9   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 10  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 11  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 12  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 13  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 14  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 15  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 16  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 17  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 18  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 19  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
#
#                                                   dst  dst_exists
# 0   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 1   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 2   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 3   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 4   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 5   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 6   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 7   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 8   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 9   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 10  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 11  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 12  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 13  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 14  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 15  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 16  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 17  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 18  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
# 19  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...        True
#    network location old_channel new_channel  n_stations
# 0       T1       N1         GPE         DPE          12
# 1       T1       N1         GPN         DPN          12
# 2       T1       N1         GPZ         DPZ          12
# 3       T1       N2         GPE         DPE          12
# 4       T1       N2         GPN         DPN          12
# 5       T1       N2         GPZ         DPZ          12
# 6       T1       N3         GPE         DPE          12
# 7       T1       N3         GPN         DPN          12
# 8       T1       N3         GPZ         DPZ          12
# 9       T3       N4         GPE         DPE          12
# 10      T3       N4         GPN         DPN          12
# 11      T3       N4         GPZ         DPZ          12
# Destination files already exist: 57

# %% [markdown]
# ## Conversion function
#
# For each `GP?` day file:
#
# 1. read the MiniSEED file;
# 2. detrend and taper;
# 3. low-pass filter at 200 Hz;
# 4. decimate by 2, producing 500 Hz data;
# 5. change channel code from `GP?` to `DP?`;
# 6. write the converted day file to the corresponding `DP?.D` SDS directory.

# %%
def convert_gp_day_file_to_dp(
    src_path: Path,
    sds_root: Path,
    dry_run: bool = True,
    overwrite: bool = False,
    lowpass_freq_hz: float = 200.0,
    lowpass_corners: int = 4,
    expected_input_rate_hz: float = 1000.0,
    output_rate_hz: float = 500.0,
    decimation_factor: int = 2,
) -> dict:
    """Convert one GP? SDS day file to a DP? 500 Hz day file."""
    src_path = Path(src_path)
    sds_root = Path(sds_root)

    out = {
        "src": str(src_path),
        "dst": "",
        "status": "unknown",
        "message": "",
        "network": "",
        "station": "",
        "location": "",
        "old_channel": "",
        "new_channel": "",
        "year": "",
        "jday": "",
        "n_traces": 0,
        "input_sampling_rate_hz": np.nan,
        "output_sampling_rate_hz": np.nan,
    }

    try:
        if is_appledouble(src_path):
            out["status"] = "skip_appledouble"
            return out

        meta = parse_sds_filename(src_path)
        out.update({
            "network": meta["network"],
            "station": meta["station"],
            "location": meta["location"],
            "old_channel": meta["channel"],
            "year": meta["year"],
            "jday": meta["jday"],
        })

        if meta["channel"] not in CHANNEL_MAP:
            out["status"] = "skip_not_gp"
            out["message"] = f"Channel {meta['channel']} is not in CHANNEL_MAP"
            return out

        new_channel = CHANNEL_MAP[meta["channel"]]
        out["new_channel"] = new_channel
        dst_path = make_sds_output_path(src_path, sds_root, new_channel)
        out["dst"] = str(dst_path)

        if dst_path.exists() and not overwrite:
            out["status"] = "exists"
            out["message"] = "Destination exists and overwrite=False"
            return out

        if dry_run:
            out["status"] = "dry_run"
            out["message"] = "Would convert and write"
            return out

        st = read(str(src_path))
        out["n_traces"] = len(st)
        if len(st) == 0:
            out["status"] = "empty_stream"
            return out

        rates = sorted(set(float(tr.stats.sampling_rate) for tr in st))
        out["input_sampling_rate_hz"] = rates[0] if len(rates) == 1 else np.nan

        for tr in st:
            sr = float(tr.stats.sampling_rate)
            if abs(sr - expected_input_rate_hz) > 1e-6:
                raise ValueError(f"Expected {expected_input_rate_hz} Hz but found {sr} Hz in {tr.id}")

            tr.detrend("linear")
            tr.taper(max_percentage=0.02)
            tr.filter("lowpass", freq=lowpass_freq_hz, corners=lowpass_corners, zerophase=True)
            tr.decimate(factor=decimation_factor, no_filter=True)

            if abs(float(tr.stats.sampling_rate) - output_rate_hz) > 1e-6:
                raise ValueError(f"Decimation failed: output rate is {tr.stats.sampling_rate} Hz")

            tr.stats.channel = new_channel

        dst_path.parent.mkdir(parents=True, exist_ok=True)
        st.write(str(dst_path), format="MSEED")

        out["output_sampling_rate_hz"] = float(st[0].stats.sampling_rate)
        out["status"] = "written"
        out["message"] = "Converted successfully"
        return out

    except Exception as e:
        out["status"] = "failed"
        out["message"] = repr(e)
        return out

# %% [markdown]
# ## Run conversion
#
# First run with `DRY_RUN = True`. If the report looks right, change `DRY_RUN = False` in the configuration cell and rerun from here.

# %%
rows = []

for i, src in enumerate(gp_files, start=1):
    result = convert_gp_day_file_to_dp(
        src,
        sds_root=SDS_ROOT,
        dry_run=DRY_RUN,
        overwrite=OVERWRITE,
        lowpass_freq_hz=LOWPASS_FREQ_HZ,
        lowpass_corners=LOWPASS_CORNERS,
        expected_input_rate_hz=INPUT_SAMPLING_RATE_HZ,
        output_rate_hz=OUTPUT_SAMPLING_RATE_HZ,
        decimation_factor=DECIMATION_FACTOR,
    )
    rows.append(result)

    if i <= 10 or result["status"] in {"failed", "written"}:
        print(f"[{i}/{len(gp_files)}] {result['status']}: {src.name} -> {Path(result['dst']).name if result['dst'] else ''}")
        if result["message"]:
            print("   ", result["message"])

report_df = pd.DataFrame(rows)
REPORT_CSV.parent.mkdir(parents=True, exist_ok=True)
report_df.to_csv(REPORT_CSV, index=False)

print("Report written to:", REPORT_CSV)
if len(report_df):
    display(report_df["status"].value_counts().to_frame("count"))
    display(report_df.head(20))
# Out:
# /opt/anaconda3/envs/flovopy_plus/lib/python3.12/site-packages/obspy/io/mseed/core.py:773: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# [1/246] written: T1.05207.N1.GPE.D.2026.136 -> T1.05207.N1.DPE.D.2026.136
#     Converted successfully
# [2/246] written: T1.05207.N1.GPE.D.2026.137 -> T1.05207.N1.DPE.D.2026.137
#     Converted successfully
# [3/246] written: T1.05207.N3.GPE.D.2026.139 -> T1.05207.N3.DPE.D.2026.139
#     Converted successfully
# [4/246] written: T1.05207.N1.GPN.D.2026.136 -> T1.05207.N1.DPN.D.2026.136
#     Converted successfully
# [5/246] written: T1.05207.N1.GPN.D.2026.137 -> T1.05207.N1.DPN.D.2026.137
#     Converted successfully
# [6/246] written: T1.05207.N3.GPN.D.2026.139 -> T1.05207.N3.DPN.D.2026.139
#     Converted successfully
# [7/246] written: T1.05207.N1.GPZ.D.2026.136 -> T1.05207.N1.DPZ.D.2026.136
#     Converted successfully
# [8/246] written: T1.05207.N1.GPZ.D.2026.137 -> T1.05207.N1.DPZ.D.2026.137
#     Converted successfully
# [9/246] written: T1.05207.N3.GPZ.D.2026.139 -> T1.05207.N3.DPZ.D.2026.139
#     Converted successfully
#     Converted successfully
# [86/246] written: T1.08405.N1.GPZ.D.2026.137 -> T1.08405.N1.DPZ.D.2026.137
#     Converted successfully
# [87/246] written: T1.08405.N2.GPZ.D.2026.137 -> T1.08405.N2.DPZ.D.2026.137
#     Converted successfully
# [88/246] written: T1.08405.N2.GPZ.D.2026.138 -> T1.08405.N2.DPZ.D.2026.138
#     Converted successfully
# [89/246] written: T1.08405.N2.GPZ.D.2026.139 -> T1.08405.N2.DPZ.D.2026.139
#     Converted successfully
# [90/246] written: T1.08405.N3.GPZ.D.2026.139 -> T1.08405.N3.DPZ.D.2026.139
#     Converted successfully
# [91/246] written: T1.10800.N1.GPE.D.2026.136 -> T1.10800.N1.DPE.D.2026.136
#     Converted successfully
# [92/246] written: T1.10800.N1.GPE.D.2026.137 -> T1.10800.N1.DPE.D.2026.137
#     Converted successfully
# [93/246] written: T1.10800.N3.GPE.D.2026.139 -> T1.10800.N3.DPE.D.2026.139
#     Converted successfully
# [94/246] written: T1.10800.N1.GPN.D.2026.136 -> T1.10800.N1.DPN.D.2026.136
#     Converted successfully
# [95/246] written: T1.10800.N1.GPN.D.2026.137 -> T1.10800.N1.DPN.D.2026.137
#     Converted successfully
# [96/246] written: T1.10800.N3.GPN.D.2026.139 -> T1.10800.N3.DPN.D.2026.139
#     Converted successfully
# [97/246] written: T1.10800.N1.GPZ.D.2026.136 -> T1.10800.N1.DPZ.D.2026.136
#     Converted successfully
# [98/246] written: T1.10800.N1.GPZ.D.2026.137 -> T1.10800.N1.DPZ.D.2026.137
#     Converted successfully
# [99/246] written: T1.10800.N3.GPZ.D.2026.139 -> T1.10800.N3.DPZ.D.2026.139
#     Converted successfully
# [100/246] written: T1.10814.N2.GPE.D.2026.137 -> T1.10814.N2.DPE.D.2026.137
#     Converted successfully
# [101/246] written: T1.10814.N2.GPE.D.2026.138 -> T1.10814.N2.DPE.D.2026.138
#     Converted successfully
# [102/246] written: T1.10814.N2.GPE.D.2026.139 -> T1.10814.N2.DPE.D.2026.139
#     Converted successfully
# [103/246] written: T1.10814.N2.GPN.D.2026.137 -> T1.10814.N2.DPN.D.2026.137
#     Converted successfully
# [104/246] written: T1.10814.N2.GPN.D.2026.138 -> T1.10814.N2.DPN.D.2026.138
#     Converted successfully
# [105/246] written: T1.10814.N2.GPN.D.2026.139 -> T1.10814.N2.DPN.D.2026.139
#     Converted successfully
# [106/246] written: T1.10814.N2.GPZ.D.2026.137 -> T1.10814.N2.DPZ.D.2026.137
#     Converted successfully
# [107/246] written: T1.10814.N2.GPZ.D.2026.138 -> T1.10814.N2.DPZ.D.2026.138
#     Converted successfully
# [108/246] written: T1.10814.N2.GPZ.D.2026.139 -> T1.10814.N2.DPZ.D.2026.139
#     Converted successfully
# [109/246] written: T1.11005.N2.GPE.D.2026.137 -> T1.11005.N2.DPE.D.2026.137
#     Converted successfully
# [110/246] written: T1.11005.N2.GPN.D.2026.137 -> T1.11005.N2.DPN.D.2026.137
#     Converted successfully
# [136/246] written: T1.11611.N2.GPZ.D.2026.137 -> T1.11611.N2.DPZ.D.2026.137
#     Converted successfully
# [137/246] written: T1.11611.N2.GPZ.D.2026.138 -> T1.11611.N2.DPZ.D.2026.138
#     Converted successfully
# [138/246] written: T1.11611.N2.GPZ.D.2026.139 -> T1.11611.N2.DPZ.D.2026.139
#     Converted successfully
# [139/246] written: T1.12005.N1.GPE.D.2026.136 -> T1.12005.N1.DPE.D.2026.136
#     Converted successfully
# [140/246] written: T1.12005.N1.GPE.D.2026.137 -> T1.12005.N1.DPE.D.2026.137
#     Converted successfully
# [141/246] written: T1.12005.N3.GPE.D.2026.139 -> T1.12005.N3.DPE.D.2026.139
#     Converted successfully
# [142/246] written: T1.12005.N1.GPN.D.2026.136 -> T1.12005.N1.DPN.D.2026.136
#     Converted successfully
# [143/246] written: T1.12005.N1.GPN.D.2026.137 -> T1.12005.N1.DPN.D.2026.137
#     Converted successfully
# [144/246] written: T1.12005.N3.GPN.D.2026.139 -> T1.12005.N3.DPN.D.2026.139
#     Converted successfully
# [145/246] written: T1.12005.N1.GPZ.D.2026.136 -> T1.12005.N1.DPZ.D.2026.136
#     Converted successfully
# [146/246] written: T1.12005.N1.GPZ.D.2026.137 -> T1.12005.N1.DPZ.D.2026.137
#     Converted successfully
# [147/246] written: T1.12005.N3.GPZ.D.2026.139 -> T1.12005.N3.DPZ.D.2026.139
#     Converted successfully
# [148/246] written: T1.12018.N2.GPE.D.2026.137 -> T1.12018.N2.DPE.D.2026.137
#     Converted successfully
# [149/246] written: T1.12018.N2.GPE.D.2026.138 -> T1.12018.N2.DPE.D.2026.138
#     Converted successfully
# [150/246] written: T1.12018.N2.GPE.D.2026.139 -> T1.12018.N2.DPE.D.2026.139
#     Converted successfully
# [151/246] written: T1.12018.N2.GPN.D.2026.137 -> T1.12018.N2.DPN.D.2026.137
#     Converted successfully
# [152/246] written: T1.12018.N2.GPN.D.2026.138 -> T1.12018.N2.DPN.D.2026.138
#     Converted successfully
# [153/246] written: T1.12018.N2.GPN.D.2026.139 -> T1.12018.N2.DPN.D.2026.139
#     Converted successfully
# [154/246] written: T1.12018.N2.GPZ.D.2026.137 -> T1.12018.N2.DPZ.D.2026.137
#     Converted successfully
# [155/246] written: T1.12018.N2.GPZ.D.2026.138 -> T1.12018.N2.DPZ.D.2026.138
#     Converted successfully
# [156/246] written: T1.12018.N2.GPZ.D.2026.139 -> T1.12018.N2.DPZ.D.2026.139
#     Converted successfully
# [157/246] written: T1.12402.N1.GPE.D.2026.136 -> T1.12402.N1.DPE.D.2026.136
#     Converted successfully
# [158/246] written: T1.12402.N1.GPE.D.2026.137 -> T1.12402.N1.DPE.D.2026.137
#     Converted successfully
# [159/246] written: T1.12402.N3.GPE.D.2026.139 -> T1.12402.N3.DPE.D.2026.139
#     Converted successfully
# [160/246] written: T1.12402.N1.GPN.D.2026.136 -> T1.12402.N1.DPN.D.2026.136
#     Converted successfully
# [161/246] written: T1.12402.N1.GPN.D.2026.137 -> T1.12402.N1.DPN.D.2026.137
#     Converted successfully
# [162/246] written: T1.12402.N3.GPN.D.2026.139 -> T1.12402.N3.DPN.D.2026.139
#     Converted successfully
# [163/246] written: T1.12402.N1.GPZ.D.2026.136 -> T1.12402.N1.DPZ.D.2026.136
#     Converted successfully
# [164/246] written: T1.12402.N1.GPZ.D.2026.137 -> T1.12402.N1.DPZ.D.2026.137
#     Converted successfully
# [165/246] written: T1.12402.N3.GPZ.D.2026.139 -> T1.12402.N3.DPZ.D.2026.139
#     Converted successfully
# [166/246] written: T1.12413.N2.GPE.D.2026.137 -> T1.12413.N2.DPE.D.2026.137
#     Converted successfully
# [167/246] written: T1.12413.N2.GPE.D.2026.138 -> T1.12413.N2.DPE.D.2026.138
#     Converted successfully
# [168/246] written: T1.12413.N2.GPE.D.2026.139 -> T1.12413.N2.DPE.D.2026.139
#     Converted successfully
# [169/246] written: T1.12413.N2.GPN.D.2026.137 -> T1.12413.N2.DPN.D.2026.137
#     Converted successfully
# [170/246] written: T1.12413.N2.GPN.D.2026.138 -> T1.12413.N2.DPN.D.2026.138
#     Converted successfully
# [171/246] written: T1.12413.N2.GPN.D.2026.139 -> T1.12413.N2.DPN.D.2026.139
#     Converted successfully
# [172/246] written: T1.12413.N2.GPZ.D.2026.137 -> T1.12413.N2.DPZ.D.2026.137
#     Converted successfully
# [173/246] written: T1.12413.N2.GPZ.D.2026.138 -> T1.12413.N2.DPZ.D.2026.138
#     Converted successfully
# [174/246] written: T1.12413.N2.GPZ.D.2026.139 -> T1.12413.N2.DPZ.D.2026.139
#     Converted successfully
# [175/246] written: T1.12801.N1.GPE.D.2026.136 -> T1.12801.N1.DPE.D.2026.136
#     Converted successfully
# [176/246] written: T1.12801.N1.GPE.D.2026.137 -> T1.12801.N1.DPE.D.2026.137
#     Converted successfully
# [177/246] written: T1.12801.N3.GPE.D.2026.139 -> T1.12801.N3.DPE.D.2026.139
#     Converted successfully
# [178/246] written: T1.12801.N1.GPN.D.2026.136 -> T1.12801.N1.DPN.D.2026.136
#     Converted successfully
# [179/246] written: T1.12801.N1.GPN.D.2026.137 -> T1.12801.N1.DPN.D.2026.137
#     Converted successfully
# [180/246] written: T1.12801.N3.GPN.D.2026.139 -> T1.12801.N3.DPN.D.2026.139
#     Converted successfully
# [181/246] written: T1.12801.N1.GPZ.D.2026.136 -> T1.12801.N1.DPZ.D.2026.136
#     Converted successfully
# [182/246] written: T1.12801.N1.GPZ.D.2026.137 -> T1.12801.N1.DPZ.D.2026.137
#     Converted successfully
# [183/246] written: T1.12801.N3.GPZ.D.2026.139 -> T1.12801.N3.DPZ.D.2026.139
#     Converted successfully
# [184/246] written: T1.12815.N2.GPE.D.2026.137 -> T1.12815.N2.DPE.D.2026.137
#     Converted successfully
# [185/246] written: T1.12815.N2.GPE.D.2026.138 -> T1.12815.N2.DPE.D.2026.138
#     Converted successfully
# [236/246] written: T3.04050.N4.GPN.D.2026.139 -> T3.04050.N4.DPN.D.2026.139
#     Converted successfully
# [237/246] written: T3.04050.N4.GPZ.D.2026.139 -> T3.04050.N4.DPZ.D.2026.139
#     Converted successfully
# [238/246] written: T3.04644.N4.GPE.D.2026.139 -> T3.04644.N4.DPE.D.2026.139
#     Converted successfully
# [239/246] written: T3.04644.N4.GPN.D.2026.139 -> T3.04644.N4.DPN.D.2026.139
#     Converted successfully
# [240/246] written: T3.04644.N4.GPZ.D.2026.139 -> T3.04644.N4.DPZ.D.2026.139
#     Converted successfully
# [241/246] written: T3.05447.N4.GPE.D.2026.139 -> T3.05447.N4.DPE.D.2026.139
#     Converted successfully
# [242/246] written: T3.05447.N4.GPN.D.2026.139 -> T3.05447.N4.DPN.D.2026.139
#     Converted successfully
# [243/246] written: T3.05447.N4.GPZ.D.2026.139 -> T3.05447.N4.DPZ.D.2026.139
#     Converted successfully
# [244/246] written: T3.06241.N4.GPE.D.2026.139 -> T3.06241.N4.DPE.D.2026.139
#     Converted successfully
# [245/246] written: T3.06241.N4.GPN.D.2026.139 -> T3.06241.N4.DPN.D.2026.139
#     Converted successfully
# [246/246] written: T3.06241.N4.GPZ.D.2026.139 -> T3.06241.N4.DPZ.D.2026.139
#     Converted successfully
# Report written to: /Volumes/tachyon/LBSSP_DATA/nodal_sds_position_codes/downsample_GP_to_DP_report.csv
#          count
# status
# written    246
#                                                   src  \
# 0   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 1   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 2   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 3   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 4   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 5   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 6   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 7   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 8   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 9   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 10  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 11  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 12  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 13  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 14  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 15  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 16  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 17  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 18  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
# 19  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...
#
#                                                   dst   status  \
# 0   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 1   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 2   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 3   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 4   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 5   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 6   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 7   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 8   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 9   /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 10  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 11  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 12  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 13  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 14  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 15  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 16  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 17  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 18  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
# 19  /Volumes/tachyon/LBSSP_DATA/nodal_sds_position...  written
#
#                    message network station location old_channel new_channel  \
# 0   Converted successfully      T1   05207       N1         GPE         DPE
# 1   Converted successfully      T1   05207       N1         GPE         DPE
# 2   Converted successfully      T1   05207       N3         GPE         DPE
# 3   Converted successfully      T1   05207       N1         GPN         DPN
# 4   Converted successfully      T1   05207       N1         GPN         DPN
# 5   Converted successfully      T1   05207       N3         GPN         DPN
# 6   Converted successfully      T1   05207       N1         GPZ         DPZ
# 7   Converted successfully      T1   05207       N1         GPZ         DPZ
# 8   Converted successfully      T1   05207       N3         GPZ         DPZ
# 9   Converted successfully      T1   06004       N1         GPE         DPE
# 10  Converted successfully      T1   06004       N1         GPE         DPE
# 11  Converted successfully      T1   06004       N3         GPE         DPE
# 12  Converted successfully      T1   06004       N1         GPN         DPN
# 13  Converted successfully      T1   06004       N1         GPN         DPN
# 14  Converted successfully      T1   06004       N3         GPN         DPN
# 15  Converted successfully      T1   06004       N1         GPZ         DPZ
# 16  Converted successfully      T1   06004       N1         GPZ         DPZ
# 17  Converted successfully      T1   06004       N3         GPZ         DPZ
# 18  Converted successfully      T1   06809       N1         GPE         DPE
# 19  Converted successfully      T1   06809       N1         GPE         DPE
#
#     year jday  n_traces  input_sampling_rate_hz  output_sampling_rate_hz
# 0   2026  136         1                  1000.0                    500.0
# 1   2026  137         1                  1000.0                    500.0
# 2   2026  139         1                  1000.0                    500.0
# 3   2026  136         1                  1000.0                    500.0
# 4   2026  137         1                  1000.0                    500.0
# 5   2026  139         1                  1000.0                    500.0
# 6   2026  136         1                  1000.0                    500.0
# 7   2026  137         1                  1000.0                    500.0
# 8   2026  139         1                  1000.0                    500.0
# 9   2026  136         1                  1000.0                    500.0
# 10  2026  137         1                  1000.0                    500.0
# 11  2026  139         1                  1000.0                    500.0
# 12  2026  136         1                  1000.0                    500.0
# 13  2026  137         1                  1000.0                    500.0
# 14  2026  139         1                  1000.0                    500.0
# 15  2026  136         1                  1000.0                    500.0
# 16  2026  137         1                  1000.0                    500.0
# 17  2026  139         1                  1000.0                    500.0
# 18  2026  136         1                  1000.0                    500.0
# 19  2026  137         1                  1000.0                    500.0

# %% [markdown]
# ## Sanity checks
#
# These checks compare `GPZ` availability with `DPZ` availability after conversion. If `DRY_RUN = False`, the `DPZ` station list should include both original 500 Hz D nodes and converted 1000 Hz G nodes.

# %%
gpz_df = summarize_sds_station_channels(SDS_ROOT, channel_glob="GPZ")
dpz_df = summarize_sds_station_channels(SDS_ROOT, channel_glob="DPZ")

print("GPZ day files:", len(gpz_df))
print("DPZ day files:", len(dpz_df))

if len(gpz_df):
    print("
GPZ stations by network/location:")
    display(gpz_df.groupby(["network", "location"])["station"].nunique().reset_index(name="n_stations"))

if len(dpz_df):
    print("
DPZ stations by network/location:")
    display(dpz_df.groupby(["network", "location"])["station"].nunique().reset_index(name="n_stations"))

# Detailed station list for T1 can be useful for the LBSSP line.
for loc in sorted(set(dpz_df["location"]) if len(dpz_df) else []):
    stations = sorted(dpz_df[(dpz_df["network"] == "T1") & (dpz_df["location"] == loc)]["station"].unique())
    if stations:
        print(f"
T1 {loc} DPZ stations: {len(stations)}")
        print(stations)
# Out:
#   Cell In[7], line 8
#     print("
#           ^
# SyntaxError: unterminated string literal (detected at line 8)

# %% [markdown]
# ## Optional: verify one converted file
#
# Set `example_dst` to a file from the report with status `written`, then read it back and check that it is 500 Hz and has a `DP?` channel code.

# %%
written = report_df[report_df["status"].eq("written")].copy() if "report_df" in globals() else pd.DataFrame()

if len(written):
    example_dst = Path(written.iloc[0]["dst"])
    st_test = read(str(example_dst))
    print(example_dst)
    print(st_test)
    print("sampling rates:", sorted(set(tr.stats.sampling_rate for tr in st_test)))
    print("channels:", sorted(set(tr.stats.channel for tr in st_test)))
else:
    print("No files were written in this run. If this was a dry run, set DRY_RUN = False and rerun the conversion cell.")

# %% [markdown]
# ## Next step
#
# After successful conversion, the refactored `90_*` notebook can process:
#
# ```python
# channel = "DPZ"       # for detection
# channels = "DP?"      # for extraction and SEG-Y shot gathers
# ```
#
# and it should include both the original 500 Hz D nodes and the downsampled former G nodes.
